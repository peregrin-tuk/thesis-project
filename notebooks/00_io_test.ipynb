# %%
import sys, os
import muspy

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

# %%
from src.io.record_midi import MidiInput
from src.io import output
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\Eric\miniconda3\envs\mpro\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
input = MidiInput(tempo=30)
# Out:
# [IO] "MPK Mini Mk II 0" connected as input port

# %%
midi = input.recordNotes(4)
# Out:
# [IO] NOW RECORDING ...
# [REC] 62 64 65 67
# [IO] recording successful.

# %%
input.close_port()
# Out:
# [IO] Input port "MPK Mini Mk II 0" closed.

# %%
mu = muspy.from_mido(midi)
mu.tracks[0].notes
# Out:
# [Note(time=2031, pitch=62, duration=198, velocity=85),
#  Note(time=2321, pitch=64, duration=325, velocity=72),
#  Note(time=2687, pitch=65, duration=38, velocity=83),
#  Note(time=2760, pitch=67, duration=171, velocity=88)]

# %%
from src.io import conversion
pm = conversion.mido_to_pretty_midi(midi)
pm.instruments[0].notes
# Out:
# [Note(start=2.115625, end=2.321875, pitch=62, velocity=85),
#  Note(start=2.417708, end=2.756250, pitch=64, velocity=72),
#  Note(start=2.798958, end=2.838542, pitch=65, velocity=83),
#  Note(start=2.875000, end=3.053125, pitch=67, velocity=88)]

# %%
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
# Out:
# note_off channel=0 note=67 velocity=0 time=171
# note_on channel=0 note=67 velocity=88 time=35
# note_off channel=0 note=65 velocity=0 time=38
# note_on channel=0 note=65 velocity=83 time=41
# note_off channel=0 note=64 velocity=0 time=325
# note_on channel=0 note=64 velocity=72 time=92
# note_off channel=0 note=62 velocity=0 time=198
# note_on channel=0 note=62 velocity=85 time=2031

# %%
output.synthesizeMidi(midi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-483937a4dd17> in <module>
# ----> 1 output.synthesizeMidi(midi)
#
# d:\FH\Masterarbeit\Project\notebooks\..\src\io\output.py in synthesizeMidi(midi)
#      81     """
#      82     if midi is not None:
# ---> 83         display(Audio(midi.fluidsynth(fs=16000), rate=16000))
#      84     else:
#      85         print('[IO] Output error: The midi object is empty.')
#
# AttributeError: 'MidiFile' object has no attribute 'fluidsynth'

# %%
output.pianoRoll(midi)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16826">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="10acbc2a-2132-4d85-b504-562a7171d9b4" data-root-id="16825"></div>

# %%
output.saveMidiFile(midi, '../midi/output/io-test.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\io-test.mid
