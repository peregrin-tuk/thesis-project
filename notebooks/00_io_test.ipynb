# %%
import sys, os

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

# %%
from src.io.record_midi import MidiInput
from src.io import output

# %%
input = MidiInput()
# Out:
# [IO] "MPK Mini Mk II 0" connected as input port
# [IO] Input port "MPK Mini Mk II 0" closed.

# %%
midi = input.recordNotes(12)
# Out:
# [IO] NOW RECORDING ...
# 66 65 67 69 68 64 64 64 64 64 64 64
# [IO] recording successful.

# %%
input.close_port()

# %%
midi.instruments[0].notes
# Out:
# [Note(start=11.358333, end=11.781250, pitch=66, velocity=61),
#  Note(start=11.750000, end=12.221875, pitch=65, velocity=62),
#  Note(start=12.190625, end=12.643750, pitch=67, velocity=65),
#  Note(start=12.643750, end=13.055208, pitch=69, velocity=70),
#  Note(start=13.055208, end=13.493750, pitch=68, velocity=78),
#  Note(start=13.477083, end=13.759375, pitch=64, velocity=83),
#  Note(start=13.885417, end=14.173958, pitch=64, velocity=82),
#  Note(start=14.301042, end=14.585417, pitch=64, velocity=83),
#  Note(start=14.727083, end=15.044792, pitch=64, velocity=82),
#  Note(start=15.154167, end=15.455208, pitch=64, velocity=77),
#  Note(start=15.596875, end=15.896875, pitch=64, velocity=77),
#  Note(start=16.006250, end=16.337500, pitch=64, velocity=72)]

# %%
output.synthesizeMidi(midi)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
output.pianoRoll(midi)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1304">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="31f0962c-dc66-405c-824a-a125116fde2f" data-root-id="1303"></div>

# %%
output.saveMidiFile(midi, '../output/midi.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\output\midi.mid
