# %%
import sys, os
import muspy

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

# %%
from src.io.record_midi import MidiInput
from src.io import output
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.7.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\Eric\miniconda3\envs\mpro\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
input = MidiInput(tempo=80)
# Out:
# [IO] "MPK Mini Mk II 0" connected as input port

# %%
midi = input.recordNotes(12)
# Out:
# [IO] NOW RECORDING ...
#
# [IO] recording successful.

# %%
input.close_port()
# Out:
# [IO] Input port "MPK Mini Mk II 0" closed.

# %%
mu = muspy.from_mido(midi)
mu.tracks[0].notes
# Out:
# [Note(time=4574, pitch=67, duration=103, velocity=82),
#  Note(time=4795, pitch=64, duration=80, velocity=85),
#  Note(time=5085, pitch=64, duration=87, velocity=82),
#  Note(time=5533, pitch=65, duration=90, velocity=87),
#  Note(time=5796, pitch=62, duration=90, velocity=75),
#  Note(time=6081, pitch=62, duration=104, velocity=80),
#  Note(time=6564, pitch=60, duration=97, velocity=81),
#  Note(time=6784, pitch=62, duration=108, velocity=81),
#  Note(time=7087, pitch=64, duration=90, velocity=81),
#  Note(time=7323, pitch=65, duration=102, velocity=57),
#  Note(time=7650, pitch=67, duration=95, velocity=77),
#  Note(time=7898, pitch=67, duration=112, velocity=71)]

# %%
from src.io import conversion
pm = conversion.mido_to_pretty_midi(midi)
pm.instruments[0].notes
# Out:
# [Note(start=4.764583, end=4.871875, pitch=67, velocity=82),
#  Note(start=4.994792, end=5.078125, pitch=64, velocity=85),
#  Note(start=5.296875, end=5.387500, pitch=64, velocity=82),
#  Note(start=5.763542, end=5.857292, pitch=65, velocity=87),
#  Note(start=6.037500, end=6.131250, pitch=62, velocity=75),
#  Note(start=6.334375, end=6.442708, pitch=62, velocity=80),
#  Note(start=6.837500, end=6.938542, pitch=60, velocity=81),
#  Note(start=7.066667, end=7.179167, pitch=62, velocity=81),
#  Note(start=7.382292, end=7.476042, pitch=64, velocity=81),
#  Note(start=7.628125, end=7.734375, pitch=65, velocity=57),
#  Note(start=7.968750, end=8.067708, pitch=67, velocity=77),
#  Note(start=8.227083, end=8.343750, pitch=67, velocity=71)]

# %%
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
print(midi.tracks[0].pop())
# Out:
# note_off channel=0 note=67 velocity=0 time=112
# note_on channel=0 note=67 velocity=71 time=153
# note_off channel=0 note=67 velocity=0 time=95
# note_on channel=0 note=67 velocity=77 time=225
# note_off channel=0 note=65 velocity=0 time=102
# note_on channel=0 note=65 velocity=57 time=146
# note_off channel=0 note=64 velocity=0 time=90
# note_on channel=0 note=64 velocity=81 time=195

# %%
output.synthesizeMidi(pm)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
output.pianoRoll(pm)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1088">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="db639298-8d7d-4eb1-9d8d-ded83ef709d2" data-root-id="1087"></div>

# %%
output.saveMidiFile(pm, '../midi/output/io-test.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\io-test.mid
