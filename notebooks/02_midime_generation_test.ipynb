# %% [markdown]
# # Imports

# %%
import sys, os
import tensorflow as tf

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

from note_seq import midi_to_note_sequence
from src.generation import MidiMeGenerator
from src.io import output, input as midi_input

# %% [markdown]
# # Prepare Midi

# %%
midi= []
for i in range(1,5):
    midi.append(midi_input.loadMidiFile('../midi/examples/monophonic/mii' + str(i) + '_4b.mid'))

# %% [markdown]
# # Train MidiMe

# %%
midime = MidiMeGenerator()
midime.trainFromMIDI(midi)
# Out:
# WARNING:tensorflow:Entity <bound method DescriptorBase.GetOptions of <google.protobuf.descriptor.Descriptor object at 0x000002D973490F88>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: LIVE_VARS_IN
# WARNING: Entity <bound method DescriptorBase.GetOptions of <google.protobuf.descriptor.Descriptor object at 0x000002D973490F88>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: LIVE_VARS_IN
# ...

# %% [markdown]
# # Generation Test
# ## Generate single MidiMe sequence

# %%
sequence = midime.generate(16, 0.2)
print(sequence['meta'])
output.pianoRollFromNoteSeq(sequence['sequence'])
# Out:
# {'gen_dur': 4.8917555809021, 'model': 'MidiMe', 'checkpoint': 'cat-mel_2bar_big', 'temperature': 0.2, 'training_meta': {'trained_on': [], 'train_dur': 91.60499358177185, 'steps': 100}}
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1082">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e95308a3-e224-4b2b-98e1-46ad47a3ab4c" data-root-id="1081"></div>

# %% [markdown]
# ## Generate multiple MidiMe sequences

# %%
sequences = midime.generateMultiple(10, 16, 1)
print(sequences['meta'])
output.pianoRollGridFromNoteSeq(sequences['sequences'])
# Out:
# {'gen_dur': 46.38625168800354, 'model': 'MidiMe', 'checkpoint': 'cat-mel_2bar_big', 'temperature': 1, 'training_meta': {'trained_on': [], 'train_dur': 91.60499358177185, 'steps': 100}}
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2483">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c6c0158b-0be9-4de7-b3a9-ad10a2775f7e" data-root-id="2482"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2636">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ec05963f-41c7-4a69-953d-4c032c55cabd" data-root-id="2635"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2802">Loading BokehJS ...</span>
#     </div>
# ...

# %%
for i in range(0, 10):
    output.saveNoteSeqToMidiFile(sequences['sequences'][i], '../midi/output/mii-midime-' + str(i) + '.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-0.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-1.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-2.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-3.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-4.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-5.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-6.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-7.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-8.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-midime-9.mid
