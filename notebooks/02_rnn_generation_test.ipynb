# %% [markdown]
# # Imports

# %%
import sys, os

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

from note_seq import midi_to_note_sequence, trim_note_sequence, extract_subsequence
from src.generation import MusicRNNGenerator
from src.io import output, input
from src.io.record_midi import MidiInput

# %% [markdown]
# # Initialize Models

# %%
rnn = MusicRNNGenerator()
# Out:
# [GEN] Initializing Music RNN with checkpoint 'attention_rnn'...
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from C:\Users\Eric\AppData\Local\Temp\tmpjrrnscg0\model.ckpt
# [GEN] 🎉 Initialization finished in 1.5174431800842285 sec.

# %% [markdown]
# ## Record or Load Primer

# %%
# rec = MidiInput()
# midi = rec.recordNotes(3)
# primer = midi_to_note_sequence(midi)
# rec.close_port()

# %%
midi = input.loadMidiFile('../midi/examples/monophonic/mii2_4b.mid')
primer = midi_to_note_sequence(midi)
end = (max(n.end_time for n in primer.notes) if primer.notes else 0)
start = end - 2 * 60/primer.tempos[0].qpm
# primer = extract_subsequence(primer, start, end)
# Out:
# ticks_per_quarter: 480
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# tempos {
#   qpm: 120.0
# }
# notes {
#   pitch: 68
#   velocity: 67
#   start_time: 0.0020833333333333333
#   end_time: 0.11666666666666667
# }
# notes {
#   pitch: 73
#   velocity: 63
#   start_time: 0.5145833333333333
#   end_time: 0.6104166666666666
# }
# notes {
#   pitch: 66
#   velocity: 62
#   start_time: 0.7614583333333333
#   end_time: 0.859375
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 1.259375
#   end_time: 1.3552083333333333
# }
# notes {
#   pitch: 68
#   velocity: 62
#   start_time: 1.7520833333333332
#   end_time: 1.8499999999999999
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 2.2666666666666666
#   end_time: 2.3645833333333335
# }
# notes {
#   pitch: 67
#   velocity: 62
#   start_time: 2.761458333333333
#   end_time: 3.0395833333333333
# }
# notes {
#   pitch: 66
#   velocity: 57
#   start_time: 3.0104166666666665
#   end_time: 3.221875
# }
# notes {
#   pitch: 64
#   velocity: 63
#   start_time: 3.50625
#   end_time: 3.6020833333333333
# }
# notes {
#   pitch: 60
#   velocity: 69
#   start_time: 4.002083333333333
#   end_time: 4.116666666666666
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 4.266666666666667
#   end_time: 4.364583333333333
# }
# notes {
#   pitch: 60
#   velocity: 65
#   start_time: 4.514583333333333
#   end_time: 4.595833333333333
# }
# notes {
#   pitch: 60
#   velocity: 53
#   start_time: 5.50625
#   end_time: 5.602083333333333
# }
# notes {
#   pitch: 60
#   velocity: 52
#   start_time: 5.752083333333333
#   end_time: 5.85
# }
# notes {
#   pitch: 60
#   velocity: 61
#   start_time: 6.002083333333333
#   end_time: 6.13125
# }
# notes {
#   pitch: 63
#   velocity: 71
#   start_time: 7.010416666666667
#   end_time: 7.505208333333333
# }
# notes {
#   pitch: 62
#   velocity: 69
#   start_time: 7.50625
#   end_time: 8.0
# }
# total_time: 8.0
# source_info {
#   encoding_type: MIDI
#   parser: PRETTY_MIDI
# }
# instrument_infos {
#   name: "MIDI"
# }

# %% [markdown]
# # Generation Tests
# ## Generate single RNN sequence

# %%
sequence = rnn.generate(primer, 16, 0.2)
print(sequence['meta'])
output.pianoRollFromNoteSeq(sequence['sequence'])
# Out:
# num_steps: 64
# qpm: 120.0
# seconds_per_step: 0.125
# primer_end_time: 8.0
# total_time: 16.0
# primer: ticks_per_quarter: 480
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# tempos {
#   qpm: 120.0
# }
# notes {
#   pitch: 68
#   velocity: 67
#   start_time: 0.0020833333333333333
#   end_time: 0.11666666666666667
# }
# notes {
#   pitch: 73
#   velocity: 63
#   start_time: 0.5145833333333333
#   end_time: 0.6104166666666666
# }
# notes {
#   pitch: 66
#   velocity: 62
#   start_time: 0.7614583333333333
#   end_time: 0.859375
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 1.259375
#   end_time: 1.3552083333333333
# }
# notes {
#   pitch: 68
#   velocity: 62
#   start_time: 1.7520833333333332
#   end_time: 1.8499999999999999
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 2.2666666666666666
#   end_time: 2.3645833333333335
# }
# notes {
#   pitch: 67
#   velocity: 62
#   start_time: 2.761458333333333
#   end_time: 3.0395833333333333
# }
# notes {
#   pitch: 66
#   velocity: 57
#   start_time: 3.0104166666666665
#   end_time: 3.221875
# }
# notes {
#   pitch: 64
#   velocity: 63
#   start_time: 3.50625
#   end_time: 3.6020833333333333
# }
# notes {
#   pitch: 60
#   velocity: 69
#   start_time: 4.002083333333333
#   end_time: 4.116666666666666
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 4.266666666666667
#   end_time: 4.364583333333333
# }
# notes {
#   pitch: 60
#   velocity: 65
#   start_time: 4.514583333333333
#   end_time: 4.595833333333333
# }
# notes {
#   pitch: 60
#   velocity: 53
#   start_time: 5.50625
#   end_time: 5.602083333333333
# }
# notes {
#   pitch: 60
#   velocity: 52
#   start_time: 5.752083333333333
#   end_time: 5.85
# }
# notes {
#   pitch: 60
#   velocity: 61
#   start_time: 6.002083333333333
#   end_time: 6.13125
# }
# notes {
#   pitch: 63
#   velocity: 71
#   start_time: 7.010416666666667
#   end_time: 7.505208333333333
# }
# notes {
#   pitch: 62
#   velocity: 69
#   start_time: 7.50625
#   end_time: 8.0
# }
# total_time: 8.0
# source_info {
#   encoding_type: MIDI
#   parser: PRETTY_MIDI
# }
# instrument_infos {
#   name: "MIDI"
# }
#
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -311.221832
# {'gen_dur': 0.8889989852905273, 'model': 'MusicVAE', 'checkpoint': 'attention_rnn', 'temperature': 0.2}
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1117">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6763595f-0246-45cd-a6bb-117b891849b1" data-root-id="1116"></div>

# %% [markdown]
# ## Generate multiple RNN sequences

# %%
sequences = rnn.generateMultiple(primer, 10, 16, 1)
print(sequences['meta'])
i = 0
for seq in sequences['sequences']:
    midi = note_sequence_to_pretty_midi(seq)
    seq2 = midi_to_note_sequence(midi)
    sequences['sequences'][i] = extract_subsequence(seq2, 8, 16)
    i += 1

output.pianoRollGridFromNoteSeq(sequences['sequences'])
# Out:
# num_steps: 64
# qpm: 120.0
# seconds_per_step: 0.125
# primer_end_time: 8.0
# total_time: 16.0
# primer: ticks_per_quarter: 480
# time_signatures {
#   numerator: 4
#   denominator: 4
# }
# tempos {
#   qpm: 120.0
# }
# notes {
#   pitch: 68
#   velocity: 67
#   start_time: 0.0020833333333333333
#   end_time: 0.11666666666666667
# }
# notes {
#   pitch: 73
#   velocity: 63
#   start_time: 0.5145833333333333
#   end_time: 0.6104166666666666
# }
# notes {
#   pitch: 66
#   velocity: 62
#   start_time: 0.7614583333333333
#   end_time: 0.859375
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 1.259375
#   end_time: 1.3552083333333333
# }
# notes {
#   pitch: 68
#   velocity: 62
#   start_time: 1.7520833333333332
#   end_time: 1.8499999999999999
# }
# notes {
#   pitch: 73
#   velocity: 62
#   start_time: 2.2666666666666666
#   end_time: 2.3645833333333335
# }
# notes {
#   pitch: 67
#   velocity: 62
#   start_time: 2.761458333333333
#   end_time: 3.0395833333333333
# }
# notes {
#   pitch: 66
#   velocity: 57
#   start_time: 3.0104166666666665
#   end_time: 3.221875
# }
# notes {
#   pitch: 64
#   velocity: 63
#   start_time: 3.50625
#   end_time: 3.6020833333333333
# }
# notes {
#   pitch: 60
#   velocity: 69
#   start_time: 4.002083333333333
#   end_time: 4.116666666666666
# }
# notes {
#   pitch: 60
#   velocity: 64
#   start_time: 4.266666666666667
#   end_time: 4.364583333333333
# }
# notes {
#   pitch: 60
#   velocity: 65
#   start_time: 4.514583333333333
#   end_time: 4.595833333333333
# }
# notes {
#   pitch: 60
#   velocity: 53
#   start_time: 5.50625
#   end_time: 5.602083333333333
# }
# notes {
#   pitch: 60
#   velocity: 52
#   start_time: 5.752083333333333
#   end_time: 5.85
# }
# notes {
#   pitch: 60
#   velocity: 61
#   start_time: 6.002083333333333
#   end_time: 6.13125
# }
# notes {
#   pitch: 63
#   velocity: 71
#   start_time: 7.010416666666667
#   end_time: 7.505208333333333
# }
# notes {
#   pitch: 62
#   velocity: 69
#   start_time: 7.50625
#   end_time: 8.0
# }
# total_time: 8.0
# source_info {
#   encoding_type: MIDI
#   parser: PRETTY_MIDI
# }
# instrument_infos {
#   name: "MIDI"
# }
#
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -135.997437
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -150.863113
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -120.604507
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -124.188400
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -128.336014
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -167.716919
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -143.278076
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -134.703156
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -157.458832
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -143.814514
# {'gen_dur': 8.695987701416016, 'model': 'MusicVAE', 'checkpoint': 'attention_rnn', 'temperature': 1}
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1266">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="400005b6-49cf-46d3-9105-0f01e52d0e92" data-root-id="1265"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1418">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9f6949cd-6b18-49e1-b483-d43476c04ead" data-root-id="1417"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1576">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e59cc1c9-aa25-4896-be29-2bfc7f0168ff" data-root-id="1575"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1747">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d11cea7b-860f-4b46-8710-a462db52b363" data-root-id="1746"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1915">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9e41b51e-e0e6-4036-ad02-da2e8159608d" data-root-id="1914"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2088">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="05b25b7e-5f16-4c11-bcc5-85cedf837596" data-root-id="2087"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2278">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9e79c021-7cd4-4165-b4a5-a305113ffd61" data-root-id="2277"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2469">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="82940fdf-049d-4279-abb7-eea13ea0d3d3" data-root-id="2468"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2657">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="931f8623-8e1d-48c7-8a21-967869472f2a" data-root-id="2656"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2850">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c1c2e426-08a5-4a48-8440-706e63fe7059" data-root-id="2849"></div>

# %%
for i in range(0, 10):
    output.saveNoteSeqToMidiFile(sequences['sequences'][i], '../midi/output/mii-rnn-' + str(i) + '.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-0.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-1.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-2.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-3.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-4.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-5.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-6.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-7.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-8.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-9.mid
