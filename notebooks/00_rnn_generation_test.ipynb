# %% [markdown]
# # Imports

# %%
import sys, os

root_dir = os.path.join(os.getcwd(), '..')
sys.path.append(root_dir)

from note_seq import midi_to_note_sequence, trim_note_sequence, extract_subsequence, note_sequence_to_pretty_midi
from src.generation import MusicRNNGenerator
from src.io import output, input
from src.io.record_midi import MidiInput

# %% [markdown]
# # Initialize Models

# %%
rnn = MusicRNNGenerator()
# Out:
# [GEN] Initializing Music RNN with checkpoint 'attention_rnn'...
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.
# INFO:tensorflow:Restoring parameters from C:\Users\Eric\AppData\Local\Temp\tmph3sr8nsz\model.ckpt
# [GEN] 🎉 Initialization finished in 3.061750888824463 sec.

# %% [markdown]
# ## Record or Load Primer

# %%
# rec = MidiInput()
# midi = rec.recordNotes(3)
# primer = midi_to_note_sequence(midi)
# rec.close_port()

# %%
midi = input.loadMidiFile('../midi/examples/monophonic/mii2_4b.mid')
primer = midi_to_note_sequence(midi)
end = (max(n.end_time for n in primer.notes) if primer.notes else 0)
start = end - 2 * 60/primer.tempos[0].qpm
# primer = extract_subsequence(primer, start, end)

# %% [markdown]
# # Generation Tests
# ## Generate single RNN sequence

# %%
sequence = rnn.generate(primer, 16, 0.2)
output.pianoRollFromNoteSeq(sequence['sequence'])
# Out:
# num_steps: 64
# qpm: 120.0
# seconds_per_step: 0.125
# primer_end_time: 8.0
# total_time: 16.0
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -311.476868
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a30098402e9b> in <module>
# ----> 1 sequence = rnn.generate(primer, 16, 0.2)
#       2 output.pianoRollFromNoteSeq(sequence['sequence'])
#
# d:\FH\Masterarbeit\Project\notebooks\..\src\generation\musicrnn_generator.py in generate(self, primer_sequence, length_in_quarters, temperature)
#      44         generator_options, start, end = self.__setupGeneratorOptions(primer_sequence, length_in_quarters, temperature)
#      45         generated_sequence = self.model.generate(primer_sequence, generator_options)
# ---> 46         generated_sequence = trim_note_sequence(generated_sequence, start, end)
#      47         t2 = time.time()
#      48
#
# ~\AppData\Roaming\Python\Python37\site-packages\note_seq\sequences_lib.py in trim_note_sequence(sequence, start_time, end_time)
#     109
#     110   subsequence = music_pb2.NoteSequence()
# --> 111   subsequence.CopyFrom(sequence)
#     112
#     113   del subsequence.notes[:]
#
# ~\miniconda3\envs\mpro\lib\site-packages\google\protobuf\message.py in CopyFrom(self, other_msg)
#     127       return
#     128     self.Clear()
# --> 129     self.MergeFrom(other_msg)
#     130
#     131   def Clear(self):
#
# ~\miniconda3\envs\mpro\lib\site-packages\google\protobuf\internal\python_message.py in MergeFrom(self, msg)
#    1320       raise TypeError(
#    1321           'Parameter to MergeFrom() must be instance of same class: '
# -> 1322           'expected %s got %s.' % (cls.__name__, msg.__class__.__name__))
#    1323
#    1324     assert msg is not self
#
# TypeError: Parameter to MergeFrom() must be instance of same class: expected NoteSequence got NoteSequence.

# %% [markdown]
# ## Generate multiple RNN sequences

# %%
sequences = rnn.generateMultiple(primer, 10, 16, 1)
print(sequences['meta'])
i = 0
for seq in sequences['sequences']:
    midi = note_sequence_to_pretty_midi(seq)
    seq2 = midi_to_note_sequence(midi)
    sequences['sequences'][i] = extract_subsequence(seq2, 8, 16)
    i += 1

output.pianoRollGridFromNoteSeq(sequences['sequences'])
# Out:
# num_steps: 64
# qpm: 120.0
# seconds_per_step: 0.125
# primer_end_time: 8.0
# total_time: 16.0
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -111.864380
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -155.925781
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -110.314934
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -146.430969
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -145.559845
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -130.578476
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -156.644043
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -121.297302
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -175.124390
# INFO:tensorflow:Beam search yields sequence with log-likelihood: -162.100922
# {'gen_dur': 8.907817363739014, 'model': 'MusicVAE', 'checkpoint': 'attention_rnn', 'temperature': 1}
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1078">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ec772ed7-b355-4173-a316-6fc139904bfb" data-root-id="1077"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1204">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="de8c10dc-684e-4db7-8342-bf597f3c9c6c" data-root-id="1203"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1317">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="936c83f5-8824-4ae9-a152-21861889780c" data-root-id="1316"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1467">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a8569ee6-eee6-4265-a5e6-fc0dc6644f72" data-root-id="1466"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1614">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ad2b6cd6-5a74-4daa-86dc-127be90fd468" data-root-id="1613"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1760">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a9cbe4f6-e44d-4c81-943f-1b800f511b00" data-root-id="1759"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1918">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="83d82b38-a5f4-415e-9fff-882a2a360dc1" data-root-id="1917"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2070">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="7c3b035c-0b47-441e-9fca-971232864a60" data-root-id="2069"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2235">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5ecf43f2-c534-4ef8-bdf3-00a950e83500" data-root-id="2234"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2413">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="dfc6ee70-29a4-4aa3-b3d5-73003baeba19" data-root-id="2412"></div>

# %%
for i in range(0, 10):
    output.saveNoteSeqToMidiFile(sequences['sequences'][i], '../midi/output/mii-rnn-' + str(i) + '.mid')
# Out:
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-0.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-1.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-2.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-3.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-4.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-5.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-6.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-7.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-8.mid
# [IO] file saved to:
# d:\FH\Masterarbeit\Project\midi\output\mii-rnn-9.mid
